# %% [markdown]
# # Functions

# %% [markdown]
# En este laboratorio pondremos en práctica algunos de los conceptos que hemos aprendido en los últimos días.
#
# `NOTA: En este laboratorio deberías intentar escribir todas las funciones por ti mismo utilizando solo la sintaxis más básica de Python y sin funciones como len, count, sum, max, min, in, etc. Dale una oportunidad. 🧑🏻‍💻👩🏻‍💻`
#
# La celda después de cada ejercicio contiene algunas pruebas para verificar si tu función funciona como se espera.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Escribe una función que devuelva el mayor de dos números

# %%
def greater(a,b):
    
    if a > b:
        return a
    else:
        return b

# %%
# Para testear tu función
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.023s
#
# OK

# %% [markdown]
# ## 2. Ahora escribe una función que devuelva el elemento más

# %%
def greatest(lst):
    if not lst:  
        return None  
    largest = lst[0] 
    for element in lst[1:]: 
        if element > largest:  
            largest = element  
    return largest

# %%
# Para testear tu función
test_greatest(greatest)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.024s
#
# OK

# %% [markdown]
# ## 3. Escribe una función que sume todos los elementos de una lista

# %%
def sum_all(lst):
    total = 0
    for element in lst:
        total += element
    return total

# %%
# Para testear tu función
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.024s
#
# OK

# %% [markdown]
# ## 4. Escribe otra función que multiplique todos los elementos de una lista

# %%
def mult_all(lst):
    result = 1
    for element in lst:
        result *= element
    return result if lst else 0

# %%
# Para testear tu función
test_mult(mult_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.025s
#
# OK

# %% [markdown]
# ## 5. Ahora combina esas dos ideas y escribe una función que reciba una lista y ya sea "+" o "*", y produzca el resultado acorde

# %%
def oper_all(lst, operator):
    if operator == "+":
        result = 0
        for element in lst:
            result += element
        return result
    elif operator == "*":
        result = 1
        for element in lst:
            result *= element
        return result if lst else 0
    else:
        return None

# %%
# Para testear tu función
test_operations(oper_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.026s
#
# OK

# %% [markdown]
# ## 6. Escribe una función que devuelva el factorial de un número.

# %%
def factorial(n):
    if n < 0:
        return None  
    result = 1
    for i in range(1, n + 1):
        result *= i
    return result

# %%
# Fórmula factorial
# n! = n * (n - 1) *...*1

# Este código define una función llamada "factorial" que toma una entrada "n". La función utiliza un bucle for para iterar a través del rango de números
# desde 1 hasta n+1. Para cada número en ese rango, multiplica el valor actual de x por el número en el rango. Al final del bucle,
# la función devuelve el valor final de x, que será el factorial del número de entrada "n".

# El factorial de un entero positivo n es el producto de todos los enteros positivos menores o iguales a n.
# Por ejemplo, el factorial de 6 (escrito "6!") es 6 * 5 * 4 * 3 * 2 * 1 = 720.

# Así que esta función toma una entrada de cualquier entero positivo y devuelve el factorial de ese número.

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.024s
#
# OK

# %% [markdown]
# ## 7. Escribe una función que tome una lista y devuelva una lista de los valores únicos.
#
# `NOTE: No podemos usar set. 🤔`

# %%
def unique(lst_un):
    unique_lst = []
    for element in lst_un:
        is_duplicate = False
        for unique in unique_lst:
            if element == unique:
                is_duplicate = True
                break
        if not is_duplicate:
            unique_lst.append(element)
    return unique_lst

# %%
# Para testear tu función 
test_unique(unique)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.134s
#
# OK

# %% [markdown]
# ## 8. Escribe una función que devuelva la moda de una lista, es decir: el elemento que aparece más veces.
#
# `NOTE: No se debe usar count... 🧐`

# %%
def mode_counter(arr):
    frequency = {}
    for element in arr:
        if element in frequency:
            frequency[element] += 1
        else:
            frequency[element] = 1

    max_count = 0
    mode_value = None
    for key in frequency:
        if frequency[key] > max_count:
            max_count = frequency[key]
            mode_value = key
    return mode_value

# %%
# Para testear tu función 
test_mode(mode_counter)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.032s
#
# OK

# %% [markdown]
# ## 9. Escribe una función que calcule la desviación estándar de una lista.
# `NOTE: no utilices librerías ni ninguna función ya construida. 😉`

# %%
def st_dev(list_sd):

# %%
# Para testear tu función
test_stdev(st_dev)
# Out:
# .F.FF.FFFF..FF.FF.F.F.F.F..F......F..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 2
#       1 # Para testear tu función
# ----> 2 test_stdev(st_dev)
#
# File c:\Users\david\OneDrive\Ironhack\ds-consorci-notebooks\Sesiones\S07 - Funciones\lab-functions-es-main\mod\testing.py:147, in test_stdev(fn)
#     145     arr = [random.randint(-1000,1000) for _ in range(random.randint(10,100))]
#     146     suite.addTest(TestKnown(arr,stdev(arr)))
# --> 147 unittest.TextTestRunner().run(suite)
#
# File c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\unittest\runner.py:240, in TextTestRunner.run(self, test)
#     238     startTestRun()
#     239 try:
# --> 240     test(result)
#     241 finally:
#     242     stopTestRun = getattr(result, 'stopTestRun', None)
#
# File c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\unittest\suite.py:84, in BaseTestSuite.__call__(self, *args, **kwds)
#      83 def __call__(self, *args, **kwds):
# ---> 84     return self.run(*args, **kwds)
#
# File c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\unittest\suite.py:122, in TestSuite.run(self, result, debug)
#     119         continue
#     121 if not debug:
# --> 122     test(result)
#     123 else:
#     124     test.debug()
#
# File c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\unittest\case.py:707, in TestCase.__call__(self, *args, **kwds)
#     706 def __call__(self, *args, **kwds):
# --> 707     return self.run(*args, **kwds)
#
# File c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\unittest\case.py:651, in TestCase.run(self, result)
#     649 outcome.expecting_failure = expecting_failure
#     650 with outcome.testPartExecutor(self):
# --> 651     self._callTestMethod(testMethod)
#     652 outcome.expecting_failure = False
#     653 with outcome.testPartExecutor(self):
#
# File c:\Users\david\AppData\Local\Programs\Python\Python313\Lib\unittest\case.py:606, in TestCase._callTestMethod(self, method)
#     605 def _callTestMethod(self, method):
# --> 606     if method() is not None:
#     607         warnings.warn(f'It is deprecated to return a value that is not None from a '
#     608                       f'test case ({method})', DeprecationWarning, stacklevel=3)
#
# File c:\Users\david\OneDrive\Ironhack\ds-consorci-notebooks\Sesiones\S07 - Funciones\lab-functions-es-main\mod\testing.py:142, in test_stdev.<locals>.TestKnown.runTest(self)
#     141 def runTest(self):
# --> 142     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#
# Cell In[42], line 17, in st_dev(list_sd)
#      15 epsilon = 1e-10
#      16 std_dev = variance
# ---> 17 while abs(std_dev * std_dev - variance) > epsilon:
#      18     std_dev = (std_dev + variance / std_dev) / 2
#      20 return std_dev
#
# KeyboardInterrupt:

# %% [markdown]
# ## 10. Escribe una función para verificar si una cadena es un pangrama, es decir: si contiene todas las letras del alfabeto al menos una vez. Ten en cuenta que las cadenas pueden contener caracteres que no son letras.

# %%
def pangram(string):
#tu codigo aquí

# %%
# Para testear tu función
test_pangram(pangram)

# %% [markdown]
# ## 11. Escribe una función que reciba una cadena de palabras separadas por comas y devuelva una cadena de palabras separadas por comas ordenadas alfabéticamente.
#
# `NOTA: Puedes usar sorted pero no split y definitivamente no join! 🤪`

# %%
def sort_alpha(string):
#tu codigo aquí

# %%
# Para testear tu función 
test_alpha(sort_alpha)

# %% [markdown]
# ## 12. Escribe una función para verificar si una contraseña dada es fuerte (al menos 8 caracteres, al menos una minúscula, al menos una mayúscula, al menos un número y al menos un carácter especial). Debería devolver True si es fuerte y False si no lo es.

# %%
def check_pass(password):
#tu codigo aquí

# %%
# Para testear tu función
test_pass(check_pass)
