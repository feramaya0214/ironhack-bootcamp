# %% [markdown]
#  # General Recap
#
#  Today's aim is to conduct a full analysis of the Titanic dataset, from df upload to linear regression.

# %% [markdown]
# ## 1. Importo librerías y dataset

# %%
# manejo bbdd
import pandas as pd
import numpy as np
import datetime

#gráficas
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#estadística
import math
from scipy.stats import norm
from scipy import stats #para box-cox entre otros
from scipy.stats import skew

#preprocesamiento
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

#modelos y evaluación
from sklearn.model_selection import train_test_split
from sklearn import linear_model
import statsmodels.api as sm
from statsmodels.formula.api import ols
from sklearn.metrics import mean_squared_error,r2_score

# %%
df = pd.read_csv(r"C:\Users\david\OneDrive\Ironhack\ds-consorci-notebooks\Sesiones\S46 - Machine Learning IV\titanic.csv")

# %% [markdown]
# ## 2. Initial exploration of the data
#
# - datatypes
# - Nulls (check, do not work on them yet)
# - columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 255          256         1       3  Touma, Mrs. Darwis (Hanne Youssef Razi)
# 646          647         0       3                        Cor, Mr. Liudevit
# 539          540         1       1       Frolicher, Miss. Hedwig Margaritha
# 481          482         0       2         Frost, Mr. Anthony Wood "Archie"
# 375          376         1       1    Meyer, Mrs. Edgar Joseph (Leila Saks)
# 47            48         1       3                O'Driscoll, Miss. Bridget
# 294          295         0       3                         Mineff, Mr. Ivan
# 11            12         1       1                 Bonnell, Miss. Elizabeth
# 653          654         1       3            O'Leary, Miss. Hanora "Norah"
# 129          130         0       3                       Ekstrom, Mr. Johan
#
#         Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 255  female  29.0      0      2      2650  15.2458   NaN        C
# 646    male  19.0      0      0    349231   7.8958   NaN        S
# 539  female  22.0      0      2     13568  49.5000   B39        C
# 481    male   NaN      0      0    239854   0.0000   NaN        S
# 375  female   NaN      1      0  PC 17604  82.1708   NaN        C
# 47   female   NaN      0      0     14311   7.7500   NaN        Q
# 294    male  24.0      0      0    349233   7.8958   NaN        S
# 11   female  58.0      0      0    113783  26.5500  C103        S
# 653  female   NaN      0      0    330919   7.8292   NaN        Q
# 129    male  45.0      0      0    347061   6.9750   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## 3. Categorical Data - Exploration

# %% [markdown]
# ### Activity
#
# Analizar los distintos campos categóricos. Definir tratamientos a realizar:
#
# - Corrección de categorías: value_counts? gráficas?
# - Hay algún campo que deba eliminarse por cantidad de nulos? Se podría hacer algo para evitarlo?
# - Hay algún campo que deba eliminarse ya que no aporta información?

# %% [markdown]
# ### Solución

# %%
df.Sex.value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.Ticket.value_counts()
# Out:
# Ticket
# 347082              7
# 1601                7
# CA. 2343            7
# 3101295             6
# CA 2144             6
#                    ..
# PC 17590            1
# 17463               1
# 330877              1
# 373450              1
# STON/O2. 3101282    1
# Name: count, Length: 681, dtype: int64

# %%
df = df.drop(columns="Ticket")

# %%
df.Cabin.value_counts()
# Out:
# Cabin
# G6             4
# C23 C25 C27    4
# B96 B98        4
# F2             3
# D              3
#               ..
# E17            1
# A24            1
# C50            1
# B42            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
df = df.drop(columns="Cabin")

# %%
df.Embarked.value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
# PENDIENTE IMPUTAR VACIOS DE EMBARKED

# %% [markdown]
# Variables a analizar:
# - Name -> resolvemos por feature extraction
# - Sex -> ok
# - Ticket -> drop
# - Cabin -> podríamos hacer extraction, habría que investigar más
# - Embarked -> ok

# %% [markdown]
# ### Feature extraction
# - Hay algún campo que se pueda utilizar para feature extraction?

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 605          606         0       3
# 324          325         0       3
# 518          519         1       2
# 598          599         0       3
# 847          848         0       3
# 701          702         1       1
# 634          635         0       3
# 407          408         1       2
# 444          445         1       3
# 426          427         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 605                      Lindell, Mr. Edvard Bengtsson    male  36.0      1
# 324                           Sage, Mr. George John Jr    male   NaN      8
# 518  Angle, Mrs. William A (Florence "Mary" Agnes H...  female  36.0      1
# 598                                  Boulos, Mr. Hanna    male   NaN      0
# 847                                 Markoff, Mr. Marin    male  35.0      0
# 701                   Silverthorne, Mr. Spencer Victor    male  35.0      0
# 634                                 Skoog, Miss. Mabel  female   9.0      3
# 407                     Richards, Master. William Rowe    male   3.0      1
# 444                  Johannesen-Bratthammer, Mr. Bernt    male   NaN      0
# 426        Clarke, Mrs. Charles V (Ada Maria Winfield)  female  28.0      1
#
#      Parch     Fare Embarked
# 605      0  15.5500        S
# 324      2  69.5500        S
# 518      0  26.0000        S
# 598      0   7.2250        C
# 847      0   7.8958        C
# 701      0  26.2875        S
# 634      2  27.9000        S
# 407      1  18.7500        S
# 444      0   8.1125        S
# 426      0  26.0000        S

# %%
df["title"] = df["Name"].apply(lambda x: x.split(",")[1].split(".")[0].strip())

# %%
df["title"].value_counts()
# Out:
# title
# Mr              517
# Miss            182
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Col               2
# Mlle              2
# Major             2
# Ms                1
# Mme               1
# Don               1
# Lady              1
# Sir               1
# Capt              1
# the Countess      1
# Jonkheer          1
# Name: count, dtype: int64

# %%
df["title"].value_counts()[4:]
# Out:
# title
# Dr              7
# Rev             6
# Col             2
# Mlle            2
# Major           2
# Ms              1
# Mme             1
# Don             1
# Lady            1
# Sir             1
# Capt            1
# the Countess    1
# Jonkheer        1
# Name: count, dtype: int64

# %%
df["title"].replace("Mlle", "Mrs", inplace=True)
df["title"].replace("Ms", "Miss", inplace=True)
df["title"].replace("Mme", "Miss", inplace=True)
df["title"].replace("Don", "Mr", inplace=True)
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_18928\3750617185.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["title"].replace("Mlle", "Mrs", inplace=True)
# C:\Users\david\AppData\Local\Temp\ipykernel_18928\3750617185.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["title"].replace("Ms", "Miss", inplace=True)
# C:\Users\david\AppData\Local\Temp\ipykernel_18928\3750617185.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["title"].replace("Mme", "Miss", inplace=True)
# C:\Users\david\AppData\Local\Temp\ipykernel_18928\3750617185.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["title"].replace("Don", "Mr", inplace=True)

# %%
df["title"].replace(df["title"].value_counts().index[4:], "Other", inplace=True)
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_18928\163155564.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["title"].replace(df["title"].value_counts().index[4:], "Other", inplace=True)

# %%
df["title"].value_counts()
# Out:
# title
# Mr        518
# Miss      184
# Mrs       127
# Master     40
# Other      22
# Name: count, dtype: int64

# %%
df = df.drop(['Name'], axis=1)
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female   NaN      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked  title
# 0          S     Mr
# 1          C    Mrs
# 2          S   Miss
# 3          S    Mrs
# 4          S     Mr
# ..       ...    ...
# 886        S  Other
# 887        S   Miss
# 888        S   Miss
# 889        C     Mr
# 890        Q     Mr
#
# [891 rows x 10 columns]

# %% [markdown]
# ## 4. Numerical Data - Exploration

# %% [markdown]
# ### Activity
#
# Para las distintas variables numéricas
# - Explorar nulls
# - Explorar outliers
# - Hay alguna variable a la que haya que aplicarle transformaciones (log, raiz cuadrada)?
# - Explorar correlaciones entre variables numéricas

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female   NaN      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked  title
# 0          S     Mr
# 1          C    Mrs
# 2          S   Miss
# 3          S    Mrs
# 4          S     Mr
# ..       ...    ...
# 886        S  Other
# 887        S   Miss
# 888        S   Miss
# 889        C     Mr
# 890        Q     Mr
#
# [891 rows x 10 columns]

# %% [markdown]
# ### Solución

# %% [markdown]
# Variables a analizar:
# - PClass -> ok
# - Survived -> ok
# - Age -> IMPUTAR NULOS
# - SibSp -> ok
# - Parch -> ok
# - Fare

# %%
df.Pclass.value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df.Survived.value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df.SibSp.value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df.Parch.value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %% [markdown]
# ### Transformaciones

# %%
sns.displot(df.Fare)
plt.show()

# %%
def log_transfom_clean_(x):
    if np.isfinite(x) and x!=0:
        return np.log(x)
    else:
        return np.NAN

# %%
# pd.Series(map(log_transfom_clean_, df.Fare)).hist()
# plt.show()

# %%
def sqrt_transfom_clean_(x):
    if np.isfinite(x) and x>=0:
        return np.sqrt(x)
    else:
        return np.NAN

# %%
pd.Series(map(sqrt_transfom_clean_, df.Fare)).hist()
plt.show()

# %% [markdown]
# ### Null Imputation

# %% [markdown]
# We only have the Age column with nulls... Let's fill them in, but exploring the data... are men the same age on average as women?

# %% [markdown]
# To adjust a little more, we are going to fill the NaN of the age with the median but based on some categories (gender, PClass and Title)

# %%
df.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
import seaborn as sns
sns.histplot(df.Age);

# %%
df.Age.isna().sum()
# Out:
# np.int64(177)

# %%
serie_hombres = df[df["Sex"]=="male"]["Age"]
serie_hombres
# Out:
# 0      22.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
#        ...
# 883    28.0
# 884    25.0
# 886    27.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 577, dtype: float64

# %%
sns.histplot(serie_hombres)
plt.axvline(serie_hombres.median(), c="r", label="median")
plt.axvline(serie_hombres.mean(), c="g", label="mean");

# %%
sns.boxplot(x=df.Age, y=df.Sex);

"""
Hombres: más distribuido; max es más alto
Hombres: más outliers
La mediaNA y el máximo de mujer es más joven
Ancho de las cajas: rango
Ancho respecto a la línea: simetría
"""
# Out:
# '\nHombres: más distribuido; max es más alto\nHombres: más outliers\nLa mediaNA y el máximo de mujer es más joven\nAncho de las cajas: rango\nAncho respecto a la línea: simetría\n'

# %%
df.groupby(["Pclass", "Sex"]).agg({"Age":"mean"})
# Out:
#                      Age
# Pclass Sex
# 1      female  34.611765
#        male    41.281386
# 2      female  28.722973
#        male    30.740707
# 3      female  21.750000
#        male    26.507589

# %%
df["age"] = df.groupby(["Pclass", "Sex"])["Age"].transform(lambda x: x.fillna(x.mean()))

# %%
df["age"]
# Out:
# 0      22.00
# 1      38.00
# 2      26.00
# 3      35.00
# 4      35.00
#        ...
# 886    27.00
# 887    19.00
# 888    21.75
# 889    26.00
# 890    32.00
# Name: age, Length: 891, dtype: float64

# %%
df.age.isna().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns = ["Age"], inplace=True)

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       2
# title          0
# age            0
# dtype: int64

# %% [markdown]
# ### Correlaciones

# %%
df.Embarked = df.Embarked.fillna(df["Embarked"].mode()[0])

# %%
# Feature generation
df["adult"] = df.age.apply(lambda x: 1 if x > 16 else 0)

# %%
df.drop(columns = ["title"], inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex  SibSp  Parch     Fare Embarked  \
# 0              1         0       3    male      1      0   7.2500        S
# 1              2         1       1  female      1      0  71.2833        C
# 2              3         1       3  female      0      0   7.9250        S
# 3              4         1       1  female      1      0  53.1000        S
# 4              5         0       3    male      0      0   8.0500        S
# ..           ...       ...     ...     ...    ...    ...      ...      ...
# 886          887         0       2    male      0      0  13.0000        S
# 887          888         1       1  female      0      0  30.0000        S
# 888          889         0       3  female      1      2  23.4500        S
# 889          890         1       1    male      0      0  30.0000        C
# 890          891         0       3    male      0      0   7.7500        Q
#
#        age  adult
# 0    22.00      1
# 1    38.00      1
# 2    26.00      1
# 3    35.00      1
# 4    35.00      1
# ..     ...    ...
# 886  27.00      1
# 887  19.00      1
# 888  21.75      1
# 889  26.00      1
# 890  32.00      1
#
# [891 rows x 10 columns]

# %%
from sklearn.linear_model import LinearRegression
import seaborn as sns

data_corr = df.select_dtypes(np.number)
corr_matrix=data_corr.corr(method='pearson')
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(corr_matrix, annot=True)
plt.show()

# %% [markdown]
# ## 5. Categorical Encoding

# %% [markdown]
# ### Label Encoder
# Pros and cons
# - If we have categories that have value in themselves, such as "good, bad, regular" the ideal would be not to let LabelEncoder do it automatically but to apply it manually, since the value we put can influence the weight that the algorithm gives those variables.

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass   Sex  SibSp  Parch   Fare Embarked  \
# 768          769         0       3  male      1      0  24.15        Q
#
#            age  adult
# 768  26.507589      1

# %%
df[["female", "male"]] = pd.get_dummies(df["Sex"], dtype="int")
df
# Out:
#      PassengerId  Survived  Pclass     Sex  SibSp  Parch     Fare Embarked  \
# 0              1         0       3    male      1      0   7.2500        S
# 1              2         1       1  female      1      0  71.2833        C
# 2              3         1       3  female      0      0   7.9250        S
# 3              4         1       1  female      1      0  53.1000        S
# 4              5         0       3    male      0      0   8.0500        S
# ..           ...       ...     ...     ...    ...    ...      ...      ...
# 886          887         0       2    male      0      0  13.0000        S
# 887          888         1       1  female      0      0  30.0000        S
# 888          889         0       3  female      1      2  23.4500        S
# 889          890         1       1    male      0      0  30.0000        C
# 890          891         0       3    male      0      0   7.7500        Q
#
#        age  adult  female  male
# 0    22.00      1       0     1
# 1    38.00      1       1     0
# 2    26.00      1       1     0
# 3    35.00      1       1     0
# 4    35.00      1       0     1
# ..     ...    ...     ...   ...
# 886  27.00      1       0     1
# 887  19.00      1       1     0
# 888  21.75      1       1     0
# 889  26.00      1       0     1
# 890  32.00      1       0     1
#
# [891 rows x 12 columns]

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
df["sexo"] = le.fit_transform(df["Sex"])
df
# Out:
#      PassengerId  Survived  Pclass     Sex  SibSp  Parch     Fare Embarked  \
# 0              1         0       3    male      1      0   7.2500        S
# 1              2         1       1  female      1      0  71.2833        C
# 2              3         1       3  female      0      0   7.9250        S
# 3              4         1       1  female      1      0  53.1000        S
# 4              5         0       3    male      0      0   8.0500        S
# ..           ...       ...     ...     ...    ...    ...      ...      ...
# 886          887         0       2    male      0      0  13.0000        S
# 887          888         1       1  female      0      0  30.0000        S
# 888          889         0       3  female      1      2  23.4500        S
# 889          890         1       1    male      0      0  30.0000        C
# 890          891         0       3    male      0      0   7.7500        Q
#
#        age  adult  female  male  sexo
# 0    22.00      1       0     1     1
# 1    38.00      1       1     0     0
# 2    26.00      1       1     0     0
# 3    35.00      1       1     0     0
# 4    35.00      1       0     1     1
# ..     ...    ...     ...   ...   ...
# 886  27.00      1       0     1     1
# 887  19.00      1       1     0     0
# 888  21.75      1       1     0     0
# 889  26.00      1       0     1     1
# 890  32.00      1       0     1     1
#
# [891 rows x 13 columns]

# %%
df.drop(columns=["female","Sex","sexo"], inplace=True)

# %%
df[["C", "Q", "S"]] = pd.get_dummies(df.Embarked, dtype="int")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch     Fare Embarked    age  \
# 0              1         0       3      1      0   7.2500        S  22.00
# 1              2         1       1      1      0  71.2833        C  38.00
# 2              3         1       3      0      0   7.9250        S  26.00
# 3              4         1       1      1      0  53.1000        S  35.00
# 4              5         0       3      0      0   8.0500        S  35.00
# ..           ...       ...     ...    ...    ...      ...      ...    ...
# 886          887         0       2      0      0  13.0000        S  27.00
# 887          888         1       1      0      0  30.0000        S  19.00
# 888          889         0       3      1      2  23.4500        S  21.75
# 889          890         1       1      0      0  30.0000        C  26.00
# 890          891         0       3      0      0   7.7500        Q  32.00
#
#      adult  male  C  Q  S
# 0        1     1  0  0  1
# 1        1     0  1  0  0
# 2        1     0  0  0  1
# 3        1     0  0  0  1
# 4        1     1  0  0  1
# ..     ...   ... .. .. ..
# 886      1     1  0  0  1
# 887      1     0  0  0  1
# 888      1     0  0  0  1
# 889      1     1  1  0  0
# 890      1     1  0  1  0
#
# [891 rows x 13 columns]

# %%
df.drop(columns=["Embarked","S"], inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch     Fare    age  adult  male  \
# 0              1         0       3      1      0   7.2500  22.00      1     1
# 1              2         1       1      1      0  71.2833  38.00      1     0
# 2              3         1       3      0      0   7.9250  26.00      1     0
# 3              4         1       1      1      0  53.1000  35.00      1     0
# 4              5         0       3      0      0   8.0500  35.00      1     1
# ..           ...       ...     ...    ...    ...      ...    ...    ...   ...
# 886          887         0       2      0      0  13.0000  27.00      1     1
# 887          888         1       1      0      0  30.0000  19.00      1     0
# 888          889         0       3      1      2  23.4500  21.75      1     0
# 889          890         1       1      0      0  30.0000  26.00      1     1
# 890          891         0       3      0      0   7.7500  32.00      1     1
#
#      C  Q
# 0    0  0
# 1    1  0
# 2    0  0
# 3    0  0
# 4    0  0
# ..  .. ..
# 886  0  0
# 887  0  0
# 888  0  0
# 889  1  0
# 890  0  1
#
# [891 rows x 11 columns]

# %% [markdown]
# ## 6. Numerical Features Scaling

# %% [markdown]
# Some algorithms, especially those based on distance calculations, will give more weight to features that show large changes in value, interpreting these features as artificially more important. For these algorithms, it is important that we scale our features, or that we scale features with naturally different scales, so that the features are used by the algorithm without artificial overweighting, and allow two features with different scales to be compared.

# %%
df
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch     Fare    age  adult  male  \
# 0              1         0       3      1      0   7.2500  22.00      1     1
# 1              2         1       1      1      0  71.2833  38.00      1     0
# 2              3         1       3      0      0   7.9250  26.00      1     0
# 3              4         1       1      1      0  53.1000  35.00      1     0
# 4              5         0       3      0      0   8.0500  35.00      1     1
# ..           ...       ...     ...    ...    ...      ...    ...    ...   ...
# 886          887         0       2      0      0  13.0000  27.00      1     1
# 887          888         1       1      0      0  30.0000  19.00      1     0
# 888          889         0       3      1      2  23.4500  21.75      1     0
# 889          890         1       1      0      0  30.0000  26.00      1     1
# 890          891         0       3      0      0   7.7500  32.00      1     1
#
#      C  Q
# 0    0  0
# 1    1  0
# 2    0  0
# 3    0  0
# 4    0  0
# ..  .. ..
# 886  0  0
# 887  0  0
# 888  0  0
# 889  1  0
# 890  0  1
#
# [891 rows x 11 columns]

# %% [markdown]
# ### Activity
# Review numerical features:
# - Explore and deal with outliers
# - Research how to standarize or normalize the columns

# %% [markdown]
# ## 7. Train-Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch  Fare   age  adult  male  C  \
# 574          575         0       3      0      0  8.05  16.0      0     1  0
#
#      Q
# 574  0

# %%
X = df.drop(columns = "Fare")
y = df.Fare

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
X_train.shape
# Out:
# (668, 10)

# %%
X_test.shape
# Out:
# (223, 10)

# %%
y_train.shape
# Out:
# (668,)

# %%
y_test.shape
# Out:
# (223,)

# %% [markdown]
# ## 8. Apply model

# %% [markdown]
# ### Activity
#
# Aplicar un modelo de regresión lineal para evaluar que variables son mejores predictoras del precio (Fare).
# Testear luego la capacidad de predicción de este modelo con la porción de test.

# %% [markdown]
# ### usando StatsModels

# %%
X_train_sm = sm.add_constant(X)

model = sm.OLS(y,X_train_sm).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.401
# Model:                            OLS   Adj. R-squared:                  0.394
# Method:                 Least Squares   F-statistic:                     58.94
# Date:                Thu, 21 Nov 2024   Prob (F-statistic):           4.52e-91
# Time:                        19:25:24   Log-Likelihood:                -4515.5
# No. Observations:                 891   AIC:                             9053.
# Df Residuals:                     880   BIC:                             9106.
# Df Model:                          10
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          89.9767      8.923     10.084      0.000      72.464     107.489
# PassengerId     0.0012      0.005      0.229      0.819      -0.009       0.011
# Survived        3.7109      3.454      1.074      0.283      -3.069      10.491
# Pclass        -32.4677      1.940    -16.737      0.000     -36.275     -28.660
# SibSp           6.8654      1.348      5.094      0.000       4.220       9.510
# Parch          11.0279      1.871      5.895      0.000       7.356      14.699
# age            -0.3443      0.133     -2.586      0.010      -0.606      -0.083
# adult          16.2901      5.353      3.043      0.002       5.784      26.797
# male           -1.5412      3.372     -0.457      0.648      -8.160       5.078
# C              18.9230      3.461      5.468      0.000      12.131      25.715
# Q               5.8744      4.825      1.217      0.224      -3.596      15.345
# ==============================================================================
# Omnibus:                     1022.606   Durbin-Watson:                   2.058
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           104079.523
# Skew:                           5.559   Prob(JB):                         0.00
# Kurtosis:                      54.767   Cond. No.                     3.81e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.81e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
lm = linear_model.LinearRegression()
model = lm.fit(X_train,y_train)
print("R2 value is = ",round(lm.score(X_train,y_train),2))
# Out:
# R2 value is =  0.36

# %%
predictions=lm.predict(X_test)
predictions
# Out:
# array([ 1.00123117e+01,  1.00548017e+01,  5.52017103e+01, -7.48031586e+00,
#         8.14634169e+01,  3.43966466e+01,  2.06154099e+00,  1.23041878e+02,
#         1.72559179e+01,  2.56930410e+01,  1.97239458e+01,  3.29652262e+01,
#        -4.30414520e-02,  9.20485821e+01, -3.89347742e+00,  5.67105542e+01,
#         3.43781364e+00,  5.37265589e-01,  7.10623722e+01,  2.08562694e+00,
#         6.13497496e+01,  1.26580906e-01,  5.79106398e+00,  4.22652427e+01,
#        -2.65017511e+00,  6.61333324e+01,  1.12445710e-01,  7.58932228e+01,
#         9.01941204e+01, -1.43996304e+01,  3.33949499e+01,  1.74347816e+01,
#         8.61638574e+01,  1.01253886e+02,  3.31862719e+01, -2.36054110e+00,
#        -1.80048059e+00, -3.54287525e+00,  3.53278925e+01,  8.74790120e+01,
#         4.27087940e+00,  2.13845256e+00,  3.26767790e+01,  3.49343389e+01,
#         2.04396295e+01,  1.43554755e+00,  2.43464211e+01,  4.79037446e+00,
#         3.64162943e+01,  1.26904067e+00,  6.22044553e+00,  8.03839730e+00,
#         3.81486480e+01,  6.54474463e+01,  5.22461051e+01, -8.62908524e-01,
#         3.13525101e+01,  9.81293108e+00,  1.87909025e+01,  2.84756538e+01,
#         6.58935370e+01,  2.44208586e+01,  5.70724800e+01,  2.88048282e+01,
#         6.93867808e+01,  9.99041535e+00,  3.77601774e+01, -2.76809027e+00,
#        -4.39570912e-01,  6.01302880e+01, -5.26964680e+00,  7.12500456e+01,
#         7.14088226e+01,  5.36801061e+01,  2.04033605e+00, -5.35775141e-01,
#         1.13980970e+01,  5.51466803e+01,  1.05598896e+01,  9.37767768e+01,
#        -1.83618594e+00,  5.60611501e+01,  2.98070344e+01,  5.11586023e+01,
#        -1.97040698e-01,  2.96256812e+01,  4.01198212e+00,  5.99837283e+01,
#         1.87969492e+00,  3.75279163e+01,  4.33315093e+01,  8.45973786e+01,
#        -1.21900969e-01,  3.40166238e+01, -1.71432115e+00,  3.09635167e+01,
#         8.17811571e+01,  9.49526114e+00,  5.48424954e-01,  6.10268719e+01,
#         9.54450666e+01,  4.25776642e+01,  4.38909697e+00,  3.42591902e+01,
#         1.33971666e+00,  6.90184557e+01,  1.55532978e+01,  3.46812415e-01,
#         1.76288894e+00,  4.17862865e+00,  2.01797641e+01,  1.78469342e+01,
#         5.94513339e+01,  4.13324723e+00,  1.86659176e+01,  2.11691414e-01,
#         3.36576077e+01,  1.24442869e+01,  4.21894987e+01,  5.88218555e+01,
#         7.83729252e+01, -3.53841151e+00,  3.12787382e+01, -1.33060335e-01,
#         1.00152876e+01,  9.16951720e+01,  1.77881421e+00, -2.74563189e+00,
#        -1.20573338e+00,  4.77996367e+00,  2.44904803e+01,  4.14727461e+00,
#         4.00156671e+00,  4.32371852e+01,  8.74821132e+01,  6.86301098e+01,
#         9.32277019e+01,  2.10631810e+00,  2.17983026e+00,  2.60374651e+00,
#         3.64691153e+01, -8.44571652e+00,  3.97781548e+01,  6.22775108e+00,
#         3.38855213e-02,  3.18404067e+01,  7.19597743e+01, -3.93216322e+00,
#         3.84138220e+01,  2.31391995e+00,  6.54108481e+01,  3.83275064e+00,
#         1.43331568e+00,  2.65890334e+01,  3.07942214e+01,  6.73919182e+01,
#         6.16554470e+01,  3.00021367e+01,  6.72101036e+01,  1.90768139e+00,
#         1.24243695e+02,  6.26958847e+00,  7.10148044e+01,  5.14287076e+00,
#         3.35393725e+01,  9.41801979e+01,  1.19509193e+01,  3.13974243e+01,
#         8.88135328e-02, -3.09826784e+00,  3.86240910e+01,  7.68450784e+01,
#         9.88881477e+00,  3.92729982e+01,  4.92072952e+01,  9.76978153e+00,
#         5.52179378e+01,  1.09560374e+02,  7.00936285e-01,  7.29804589e+01,
#         1.44284747e+00,  2.14682574e+01,  8.23998553e+01,  4.46295238e+01,
#         7.08045797e+01,  3.30923936e+01,  7.47522507e+01,  1.61842149e+00,
#         9.27809528e+01,  3.23058449e+01,  3.10911511e+01,  5.88973479e+01,
#         3.50238977e+01,  1.60795471e+01,  6.12136053e+01,  2.91736327e+00,
#         3.33417590e+01,  7.70476861e+01,  1.84266397e+01,  9.34379580e+01,
#        -2.28330915e+00,  3.14480134e+01,  5.33995713e+01,  8.80242381e+01,
#         4.06033438e+01, -6.92514612e+00,  3.18143682e+01,  8.96884400e+00,
#         4.49555463e+00,  2.32822473e+01,  7.22707714e+00,  3.29459735e+01,
#         9.45922492e+01, -9.78403464e+00,  1.55518509e+00,  2.54250751e+00,
#         7.33272019e+01,  1.45994673e+01,  2.54383267e+01,  2.49047297e+01,
#         4.34907162e+01,  5.45161783e+00,  6.29094359e+01])

# %%
mse=mean_squared_error(y_test, predictions)
print(mse)

rmse=math.sqrt(mse)
print(rmse)

r2=r2_score(y_test, predictions)
print(r2)
# Out:
# 685.6252545318576
# 26.18444680591625
# 0.5948151887866934
